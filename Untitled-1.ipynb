# %%
students = [
    ("Harsha",[85,90,88]),

]
def calavg(grades):
    return sum(grades)/len(grades)

def disstudents():
    print("student Grades")
    for name,grades in students:
        avg=calavg(grades)
        print(f"name: {name}, Grades: {grades}, Average: {avg:.2f}")

def addstudents():
    name=input("Enter student name: ").strip()
    gradesinput=input("enter grades separated by spaces: ")
    grades=[float(g) for g in gradesinput.split()]
    students.append((name,grades))
    print(f"student '{name}' added successfully!")

while True:
    print("student Grade Manager")
    print("1.display all students")
    print("2.add new student")
    print("3.exit")
    choice=input("Enter your choice (1/2/3): ").strip()
    if choice=="1":
        disstudents()
    elif choice=="2":
        addstudents()
    elif choice=="3":
        print("exiting program. Goodbye!")
        break
    else:
        print("invalid choice. Please enter 1, 2, or 3.")
# Out:
# student Grade Manager
# 1.display all students
# 2.add new student
# 3.exit
# student Grades
# name: Harsha, Grades: [85, 90, 88], Average: 87.67
# student Grade Manager
# 1.display all students
# 2.add new student
# 3.exit
# student 'Harsha' added successfully!
# student Grade Manager
# 1.display all students
# 2.add new student
# 3.exit
# student Grades
# name: Harsha, Grades: [85, 90, 88], Average: 87.67
# name: Harsha, Grades: [85.0, 86.0, 88.0, 99.0], Average: 89.50
# student Grade Manager
# 1.display all students
# 2.add new student
# 3.exit
# exiting program. Goodbye!
